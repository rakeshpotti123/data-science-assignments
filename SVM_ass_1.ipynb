# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import StandardScaler

from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report


from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score

# %%
Train = pd.read_csv(r'/content/SalaryData_Train(1).csv')

# %%
Test =  pd.read_csv(r'/content/SalaryData_Test(1).csv')

# %%
Train
# Out:
#        age          workclass  ...          native  Salary
# 0       39          State-gov  ...   United-States   <=50K
# 1       50   Self-emp-not-inc  ...   United-States   <=50K
# 2       38            Private  ...   United-States   <=50K
# 3       53            Private  ...   United-States   <=50K
# 4       28            Private  ...            Cuba   <=50K
# ...    ...                ...  ...             ...     ...
# 30156   27            Private  ...   United-States   <=50K
# 30157   40            Private  ...   United-States    >50K
# 30158   58            Private  ...   United-States   <=50K
# 30159   22            Private  ...   United-States   <=50K
# 30160   52       Self-emp-inc  ...   United-States    >50K
#
# [30161 rows x 14 columns]

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
import seaborn as sns
sns.catplot(
    data=Train, kind="bar",
    x="occupation", y="hoursperweek", hue="sex", palette="dark", height=12)

# %%
sns.scatterplot(x="age", y="hoursperweek",
                hue="Salary",palette="ch:r=-.2,d=.3_r",
                sizes=(1, 8), linewidth=0,
                data=Train)

# %%
sns.lineplot(x="capitalgain", y="capitalloss",
             hue="Salary",
             data=Train)

# %%
from sklearn.preprocessing import LabelEncoder


labelencoder = LabelEncoder()
Train.iloc[:, -1] = labelencoder.fit_transform(Train.iloc[:,-1])

# %%
sns.pairplot(Train)

# %%
Train
# Out:
#        age          workclass  ...          native  Salary
# 0       39          State-gov  ...   United-States       0
# 1       50   Self-emp-not-inc  ...   United-States       0
# 2       38            Private  ...   United-States       0
# 3       53            Private  ...   United-States       0
# 4       28            Private  ...            Cuba       0
# ...    ...                ...  ...             ...     ...
# 30156   27            Private  ...   United-States       0
# 30157   40            Private  ...   United-States       1
# 30158   58            Private  ...   United-States       0
# 30159   22            Private  ...   United-States       0
# 30160   52       Self-emp-inc  ...   United-States       1
#
# [30161 rows x 14 columns]

# %%
Train = pd.get_dummies(Train)

# %%
Train.shape
# Out:
# (30161, 103)

# %%
Train.head()
# Out:
#    age  educationno  ...  native_ Vietnam  native_ Yugoslavia
# 0   39           13  ...                0                   0
# 1   50           13  ...                0                   0
# 2   38            9  ...                0                   0
# 3   53            7  ...                0                   0
# 4   28           13  ...                0                   0
#
# [5 rows x 103 columns]

# %%
Test.head()
# Out:
#    age   workclass      education  ...  hoursperweek          native  Salary
# 0   25     Private           11th  ...            40   United-States   <=50K
# 1   38     Private        HS-grad  ...            50   United-States   <=50K
# 2   28   Local-gov     Assoc-acdm  ...            40   United-States    >50K
# 3   44     Private   Some-college  ...            40   United-States    >50K
# 4   34     Private           10th  ...            30   United-States   <=50K
#
# [5 rows x 14 columns]

# %%
Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
labelencoder = LabelEncoder()
Test.iloc[:, -1] = labelencoder.fit_transform(Test.iloc[:,-1])

# %%
sns.pairplot(Test)

# %%
Test = pd.get_dummies(Test)

# %%
Test
# Out:
#        age  educationno  ...  native_ Vietnam  native_ Yugoslavia
# 0       25            7  ...                0                   0
# 1       38            9  ...                0                   0
# 2       28           12  ...                0                   0
# 3       44           10  ...                0                   0
# 4       34            6  ...                0                   0
# ...    ...          ...  ...              ...                 ...
# 15055   33           13  ...                0                   0
# 15056   39           13  ...                0                   0
# 15057   38           13  ...                0                   0
# 15058   44           13  ...                0                   0
# 15059   35           13  ...                0                   0
#
# [15060 rows x 103 columns]

# %%
x_train = Train.drop(['Salary'],axis=1)

# %%
y_train = Train.iloc[:,5]

# %%
y_train
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 30156    0
# 30157    1
# 30158    0
# 30159    0
# 30160    1
# Name: Salary, Length: 30161, dtype: int64

# %%
x_test = Test.drop(['Salary'],axis=1)

# %%
y_test = Test.iloc[:,5]

# %%
y_test
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 15055    0
# 15056    0
# 15057    0
# 15058    0
# 15059    1
# Name: Salary, Length: 15060, dtype: int64

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (30161, 102) (15060, 102) (30161,) (15060,)

# %% [markdown]
# ## Grid search cv method

# %%
# ?SVC

# %%
# ?GridSearchCV

# %% [markdown]
# # Parameter estimation using grid search with cross-validation
# This examples shows how a classifier is optimized by cross-validation, which is done using the :class:~sklearn.model_selection.GridSearchCV object on a development set that comprises only half of the available labeled data.
#
# The performance of the selected hyper-parameters and trained model is then measured on a dedicated evaluation set that was not used during the model selection step.
#
# More details on tools available for model selection can be found in the sections on cross_validation and grid_search.

# %%
#clf = SVC()
#param_grid = [{'kernel':['rbf'],'gamma':[50,5,10,0.5],'C':[15,14,13,12,11,10,0.1,0.001] }]
#gsv = GridSearchCV(clf,param_grid,cv=10)
#gsv.fit(x_train,y_train)

# %%
#gsv.best_params_ , gsv.best_score_

# %%
#clf = SVC(C= 15, gamma = 50)
#clf.fit(x_train , y_train)
#y_pred = clf.predict(x_test)
#acc = accuracy_score(y_test, y_pred) * 100
#print("Accuracy =", acc)
#confusion_matrix(y_test, y_pred)

# %%
data =  pd.read_csv(r'/content/SalaryData_Test(1).csv')

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
data.iloc[:, -1] = labelencoder.fit_transform(data.iloc[:,-1])

# %%
data = pd.get_dummies(data)

# %%
data
# Out:
#        age  educationno  ...  native_ Vietnam  native_ Yugoslavia
# 0       25            7  ...                0                   0
# 1       38            9  ...                0                   0
# 2       28           12  ...                0                   0
# 3       44           10  ...                0                   0
# 4       34            6  ...                0                   0
# ...    ...          ...  ...              ...                 ...
# 15055   33           13  ...                0                   0
# 15056   39           13  ...                0                   0
# 15057   38           13  ...                0                   0
# 15058   44           13  ...                0                   0
# 15059   35           13  ...                0                   0
#
# [15060 rows x 103 columns]

# %%
x = data.drop('Salary',axis=1)

# %%
y = data['Salary']

# %%
x
# Out:
#        age  educationno  ...  native_ Vietnam  native_ Yugoslavia
# 0       25            7  ...                0                   0
# 1       38            9  ...                0                   0
# 2       28           12  ...                0                   0
# 3       44           10  ...                0                   0
# 4       34            6  ...                0                   0
# ...    ...          ...  ...              ...                 ...
# 15055   33           13  ...                0                   0
# 15056   39           13  ...                0                   0
# 15057   38           13  ...                0                   0
# 15058   44           13  ...                0                   0
# 15059   35           13  ...                0                   0
#
# [15060 rows x 102 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 15055    0
# 15056    0
# 15057    0
# 15058    0
# 15059    1
# Name: Salary, Length: 15060, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.4,random_state=0)

# %%
clf = SVC()
param_grid = [{'kernel':['rbf'],'gamma':[50,5,10,0.5],'C':[15,14,13,12,11,10,0.1,0.001] }]
gsv = GridSearchCV(clf,param_grid,cv=10)
gsv.fit(x_train,y_train)
